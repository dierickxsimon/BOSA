# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('output.csv')

sns.scatterplot(df, x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 lap = Lap_handler('testdata.xlsx')
# ----> 2 result = lap.organize_lap_data()
#       3 result
#
# File c:\Users\Simon\Documents\BOSA\lap_handler.py:33, in Lap_handler.organize_lap_data(self)
#      30     if lap_data['loop'] != self.result_json[self.current_race][-1]['loop']:
#      31         self.result_json[self.current_race][-2]['time'] = (self.result_json[self.current_race][-2]['time'][0], row['UTCTime'])
# ---> 33 self.result_json[self.current_race][-1]['time'] = (self.result_json[self.current_race][-1]['time'][0], self.df.iloc[-1]['UTCTime'])
#      35 return self.result_json
#
# AttributeError: 'Lap_handler' object has no attribute 'df'
